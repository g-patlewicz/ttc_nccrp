# %%
from pathlib import Path
TOP = Path.cwd().as_posix().replace('notebooks', '')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
from rdkit import Chem

# %%
raw_dir = Path(TOP) /'data'/'raw'
interim_dir = Path(TOP) /'data'/'interim'
processed_dir = Path(TOP) /'data'/'processed'
external_dir = Path(TOP) /'data'/'external'

# %%
def has_metal_atom(smiles):
    metal_dict = {'Na': 11 , 'Mg': 12, 'Si': 14, 'K':19, 'Ca':20, 'Mn':25, 'Fe':26, 'Cu':29, 'Zn':30, 'Co':27, 'Ni':28, 'As': 33, 'Cr':24, 'Hg':80, 'Pb':82, 'V':23, 'Al':13, 'Ag':47, 'Cd':48, 'B':5, 'Ti': 22, 'Se': 34, 'Sn': 50, 'Sb':51, 'Be': 4, 'Zr': 40, 'Nb': 41, 'Mo': 42, 'Te':52, 'Ba':56, 'W':74, 'Au': 79, 'Bi': 83}
    essential_metal_dict = {'Na': 11 , 'K':19,'Mg': 12,  'Ca':20, 'Fe':26,  'Mn':25, 'Co':27, 'Cu':29, 'Zn':30, 'Mo': 42}
    mol = Chem.MolFromSmiles(smiles)
    if mol  is None:
        return False
    return any(atom for atom in mol.GetAtoms() if atom.GetAtomicNum() in list(metal_dict.values()))

# %%
def metal_ions(smiles):
    essential_metal = ['[Na+]', '[K+]', '[Mg++]',  '[Ca++]', '[Fe+3]',  '[Mn++]', '[Co+]', '[Cu++]', '[Zn++]', '[Mo++]']
    mol = Chem.MolFromSmiles(smiles)
    if mol  is None:
        return False
    return any(mol.HasSubstructMatch(Chem.MolFromSmarts(e)) for e in essential_metal)

# %%
def P_inorg(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol  is None:
        return False
    return mol.HasSubstructMatch(Chem.MolFromSmarts('[OH]P(=[O])([OH])[OH]'))

# %%
DLCs = pd.read_excel(raw_dir/'exclusions.xlsx', sheet_name = 'DLCs2')

# %%
DLCs
# Out:
#                ID                                          SMARTS
# 0        biphenyl    c1cc(ccc1)c1ccccc1.[F,Br,Cl,#1].[F,Br,Cl,#1]
# 1    dibenzofuran   c1cccc2oc3ccccc3c12.[F,Br,Cl,#1].[F,Br,Cl,#1]
# 2  dibenzodioxin   c1ccc2Oc3ccccc3Oc2c1.[F,Br,Cl,#1].[F,Br,Cl,#1]

# %%
dlc_dict = { k:v for (k,v) in zip(DLCs['ID'], DLCs['SMARTS'])}

# %%
dlc_dict
# Out:
# {'biphenyl': 'c1cc(ccc1)c1ccccc1.[F,Br,Cl,#1].[F,Br,Cl,#1]',
#  'dibenzofuran': 'c1cccc2oc3ccccc3c12.[F,Br,Cl,#1].[F,Br,Cl,#1]',
#  'dibenzodioxin ': 'c1ccc2Oc3ccccc3Oc2c1.[F,Br,Cl,#1].[F,Br,Cl,#1]'}

# %%
HPC = pd.read_excel(raw_dir/'exclusions.xlsx', sheet_name = 'HPC')

# %%
hpc_dict = {}
for i,group in HPC.groupby('HPC'):
    key = [name for name in group['HPC'] if name!=' '][0]
    value = set(group['SMARTS'])
    hpc_dict[key]=value

# %%
hpc_dict
# Out:
# {'Aflatoxin': {'COC1=C2C3=C(C(=O)OCC3)C(=O)OC2=C2C3C=COC3OC2=C1',
#   'O=C1C=Cc2ccccc2O1',
#   'O=c1ccc2ccccc2(o1)',
#   '[#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c([#8][#6h3])c1)[#6]1=[#6]([#6](=[#8])[#8]2)[#6](=[#8])[#6][#6]1',
#   '[#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#8][#6][#6]1)=[#8])[#6](=[#8])[#8]2',
#   '[#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#6][#6]1)=[#8])[#6](=[#8])[#8]2',
#   '[#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#8][#6][#6]1)=[#8])[#6](=[#8])[#8]2'},
#  'Azoxy': {'C=[$(N=N);!$(N=N=N);!$(N=NN)]',
#   'CN=NO',
#   'NN=O',
#   '[$(C=[N+]=[N-]);!$(C=[N+]=[N-]=N);!$(C=[N+]=[N-]N)]',
#   '[C,#1]N=[NX2][C,#1]'},
#  'Benzidine': {'c2c(c1ccc(N)cc1)ccc(N)c2'},
#  'Nitroso': {'[C,c]N[NX2;v3]=O',
#   '[a;!$(a(a[A;!#1])(a[A;!#1]));!$(aa[CX3](=O)[OX2H1]);!$(aa[SX4](=[OX1])(=[OX1])([O]));!$(aaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaaaa[SX4](=[OX1])(=[OX1])([O]))]!@[$([NX2]=O)]'}}

# %%
all_fda = pd.read_excel(raw_dir/'FDA_COC.xlsx')

# %%
all_fda[all_fda['TTC_Cat'] =='COC']
# Out:
#               COC                                          SMARTS  \
# 77       biphenyl    c1cc(ccc1)c1ccccc1.[F,Br,Cl,#1].[F,Br,Cl,#1]
# 78       biphenyl    [Cl,Br,F,I]c1ccc(cc1)!@c2ccc(cc2)[Cl,Br,F,I]
# 79       biphenyl  c1cc(ccc1[!R]c2ccc(cc2)[Cl,Br,F,I])[Cl,Br,F,I]
# 80  dibenzodioxin           c1ccc2Oc3cc(ccc3(Oc2(c1)))[Cl,Br,F,I]
# 81  dibenzodioxin  c1ccc2Oc3ccccc3Oc2c1.[F,Br,Cl,#1].[F,Br,Cl,#1]
# 82   dibenzofuran   c1cccc2oc3ccccc3c12.[F,Br,Cl,#1].[F,Br,Cl,#1]
#
#                                                  Name       Source TTC_Cat  \
# 77                                                NaN          NaN     COC
# 78  Halogenated PAH (naphthalenes, biphenyls, diph...  SA31b_nogen     COC
# 79  Halogenated PAH (naphthalenes, biphenyls, diph...  SA31b_nogen     COC
# 80  Halogenated dibenzodioxins  (Nongenotoxic carc...  SA31c_nogen     COC
# 81                                                NaN          NaN     COC
# 82                                                NaN          NaN     COC
#
#    Unnamed: 5
# 77        NaN
# 78        NaN
# 79        NaN
# 80        NaN
# 81        NaN
# 82        NaN

# %%
fda_dict = {}
for i,group in all_fda[all_fda['TTC_Cat'] =='COC'].groupby('COC'):
    key = [name for name in group['COC'] if name!=' '][0]
    value = set(group['SMARTS'])
    fda_dict[key]=value

# %%
fda_dict
# Out:
# {'biphenyl': {'[Cl,Br,F,I]c1ccc(cc1)!@c2ccc(cc2)[Cl,Br,F,I]',
#   'c1cc(ccc1)c1ccccc1.[F,Br,Cl,#1].[F,Br,Cl,#1]',
#   'c1cc(ccc1[!R]c2ccc(cc2)[Cl,Br,F,I])[Cl,Br,F,I]'},
#  'dibenzodioxin': {'c1ccc2Oc3cc(ccc3(Oc2(c1)))[Cl,Br,F,I]',
#   'c1ccc2Oc3ccccc3Oc2c1.[F,Br,Cl,#1].[F,Br,Cl,#1]'},
#  'dibenzofuran': {'c1cccc2oc3ccccc3c12.[F,Br,Cl,#1].[F,Br,Cl,#1]'}}

# %%
all_fda[all_fda['TTC_Cat'] =='HPC']
# Out:
#           COC                                             SMARTS  \
# 39  Aflatoxin    COC1=C2C3=C(C(=O)OCC3)C(=O)OC2=C2C3C=COC3OC2=C1
# 40  Aflatoxin                                 O=c1ccc2ccccc2(o1)
# 41  Aflatoxin                                  O=C1C=Cc2ccccc2O1
# 42  Aflatoxin  [#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O]...
# 43  Aflatoxin  [#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c([#8][#6...
# 44  Aflatoxin  [#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c(c1)[O][...
# 45  Aflatoxin  [#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O]...
# 46      Azoxy                                               NN=O
# 47      Azoxy                                [C,#1]N=[NX2][C,#1]
# 48      Azoxy  [$(C=[N+]=[N-]);!$(C=[N+]=[N-]=N);!$(C=[N+]=[N...
# 49      Azoxy                      C=[$(N=N);!$(N=N=N);!$(N=NN)]
# 50      Azoxy                                              CN=NO
# 51      Azoxy  [$([C,#1][NX2]=[NX2][C,#1]),$([CX3]=[NX2+]=N),...
# 52      Azoxy  [$([$([CX4]([*!C])([*!C])([*!C])),$([CX4]([*!C...
# 53  Benzidine                           c2c(c1ccc(N)cc1)ccc(N)c2
# 54    Nitroso                                   [C,c]N[NX2;v3]=O
# 55    Nitroso  [a;!$(a(a[A;!#1])(a[A;!#1]));!$(aa[CX3](=O)[OX...
# 56    Nitroso  [CH3,$([CH2]([NX3])[#6]),$([CH]([NX3])([#6])[#...
# 57    Nitroso  [$([c][NX2]=O);r6;!$([c]([a]C)([a]C)[NX2]=O);!...
# 58    Nitroso                                   [$(c[NX2]=O);r5]
# 59    Nitroso                                     N(c)(c)[NX2]=O
# 60    Nitroso                            [CX4][NX3]([#6])[NX2]=O
#
#                                Name                      Source TTC_Cat  \
# 39                              NaN                         NaN     HPC
# 40                              NaN                    SA30_gen     HPC
# 41                              NaN                    SA30_gen     HPC
# 42                              NaN                         NaN     HPC
# 43                              NaN                         NaN     HPC
# 44                              NaN                         NaN     HPC
# 45                              NaN                         NaN     HPC
# 46                              NaN                         NaN     HPC
# 47          Aliphatic azo and azoxy                    SA14_gen     HPC
# 48          Aliphatic azo and azoxy                    SA14_gen     HPC
# 49          Aliphatic azo and azoxy                    SA14_gen     HPC
# 50          Aliphatic azo and azoxy                    SA14_gen     HPC
# 51                              NaN                       ochem     HPC
# 52                              NaN                       ochem     HPC
# 53                              NaN                         NaN     HPC
# 54  Alkyl and aryl N-nitroso groups                    SA21_gen     HPC
# 55           Aromatic nitroso group                    SA25_gen     HPC
# 56                              NaN               Nitroso-(SN1)     HPC
# 57                              NaN     Aromatic-nitrosos-(SN1)     HPC
# 58                              NaN  Heterocyclic-nitroso-(SN1)     HPC
# 59                              NaN               Nitroso-(SN1)     HPC
# 60                              NaN              Nitrosos-(SN2)     HPC
#
#    Unnamed: 5
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN
# 58        NaN
# 59        NaN
# 60        NaN

# %%
hpc_dict = {}
for i,group in all_fda[all_fda['TTC_Cat'] =='HPC'].groupby('COC'):
    key = [name for name in group['COC'] if name!=' '][0]
    value = set(group['SMARTS'])
    hpc_dict[key]=value

# %%
hpc_dict
# Out:
# {'Aflatoxin': {'COC1=C2C3=C(C(=O)OCC3)C(=O)OC2=C2C3C=COC3OC2=C1',
#   'O=C1C=Cc2ccccc2O1',
#   'O=c1ccc2ccccc2(o1)',
#   '[#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c([#8][#6h3])c1)[#6]1=[#6]([#6](=[#8])[#8]2)[#6](=[#8])[#6][#6]1',
#   '[#6]1[#6]2[#6]([#8][#6]1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#8][#6][#6]1)=[#8])[#6](=[#8])[#8]2',
#   '[#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#6][#6]1)=[#8])[#6](=[#8])[#8]2',
#   '[#6]1[#6]2[#6]([#8][#6]=1)[#8]c1c2c2c(c(c1)[O][CH3])[#6]1=[#6]([#6]([#8][#6][#6]1)=[#8])[#6](=[#8])[#8]2'},
#  'Azoxy': {'C=[$(N=N);!$(N=N=N);!$(N=NN)]',
#   'CN=NO',
#   'NN=O',
#   '[$(C=[N+]=[N-]);!$(C=[N+]=[N-]=N);!$(C=[N+]=[N-]N)]',
#  'Nitroso': {'N(c)(c)[NX2]=O',
#   '[$([c][NX2]=O);r6;!$([c]([a]C)([a]C)[NX2]=O);!$([c]([c]C(=O)[OH])[NX2]=O);!$([c]([c]S(=O)(=O)[OH])[NX2]=O);!$([c]([a][c]S(=O)(=O)[OH])[NX2]=O);!$([c]([a][a][c]S(=O)(=O)[OH])[NX2]=O)]',
#   '[$(c[NX2]=O);r5]',
#   '[C,c]N[NX2;v3]=O',
#   '[CH3,$([CH2]([NX3])[#6]),$([CH]([NX3])([#6])[#6])][NH,$(N([CX4])([NX3])[#6])][NX2]=O',
#   '[CX4][NX3]([#6])[NX2]=O',
#   '[a;!$(a(a[A;!#1])(a[A;!#1]));!$(aa[CX3](=O)[OX2H1]);!$(aa[SX4](=[OX1])(=[OX1])([O]));!$(aaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaaa[SX4](=[OX1])(=[OX1])([O]));!$(aaaaaa[SX4](=[OX1])(=[OX1])([O]))]!@[$([NX2]=O)]'}}

# %%
all_fda[all_fda['Source'] =='nelms']
# Out:
#             COC                                             SMARTS Name  \
# 92   carbamates           [NX3]([CX4,#1,S])([CX4,#1,S])C(=[S])[S-]  NaN
# 93   carbamates  [NX3]([CX4&!R,#1,S])([CX4&!R,#1])C(=[O,S])[O,S...  NaN
# 94          OPs                                         CP(=O)(C)O  NaN
# 95          OPs                                             SP(S)S  NaN
# 96          OPs                          OP(=[O])([O,S])N[C&!R,#1]  NaN
# 97          OPs                       [O,S]P(=[O,SX])([O,S]C)[O,S]  NaN
# 98          OPs                               OP(=[SX1])([S])[O,C]  NaN
# 99          OPs                              [#1]OP(=[O])(O[#1])C*  NaN
# 100         OPs                          [#6]OP(=[SX1])([#6])O[#6]  NaN
# 101         OPs                                       SP(=O)(S)[S]  NaN
#
#     Source     TTC_Cat Unnamed: 5
# 92   nelms  carbamates        NaN
# 93   nelms  carbamates        NaN
# 94   nelms         OPs        NaN
# 95   nelms         OPs        NaN
# 96   nelms         OPs        NaN
# 97   nelms         OPs        NaN
# 98   nelms         OPs        NaN
# 99   nelms         OPs        NaN
# 100  nelms         OPs        NaN
# 101  nelms         OPs        NaN

# %%
op_dict = {}
for i,group in all_fda[all_fda['Source'] =='nelms'].groupby('COC'):
    key = [name for name in group['COC'] if name!=' '][0]
    value = set(group['SMARTS'])
    op_dict[key]=value

# %%
op_dict
# Out:
# {'OPs': {'CP(=O)(C)O',
#   'OP(=[O])([O,S])N[C&!R,#1]',
#   'OP(=[SX1])([S])[O,C]',
#   'SP(=O)(S)[S]',
#   'SP(S)S',
#   '[#1]OP(=[O])(O[#1])C*',
#   '[#6]OP(=[SX1])([#6])O[#6]',
#   '[O,S]P(=[O,SX])([O,S]C)[O,S]'},
#  'carbamates': {'[NX3]([CX4&!R,#1,S])([CX4&!R,#1])C(=[O,S])[O,S][#6,N,#1]',
#   '[NX3]([CX4,#1,S])([CX4,#1,S])C(=[S])[S-]'}}
